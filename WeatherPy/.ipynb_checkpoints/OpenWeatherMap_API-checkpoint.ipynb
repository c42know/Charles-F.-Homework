# %%
from citipy import citipy
import numpy as np
import pandas as pd
import random
from config import api_key
import json
import requests
from pprint import pprint
import openweathermapy.core as owm
from urllib.error import HTTPError
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#setup lists for all data needed
city_list = []
cntry_code =[]
city_id = []
lat = []
lng= []
temp_max= []
wind_speed = []
humidity = []
date_time = []
cloudiness = []

#city counter
city_count = 1

#while loop for 500 unique cities
while city_count <501:
    #receive from randomn generator a random lat/lng
    lat_test = random.uniform(-180.000, 180.000)
    lng_test = random.uniform(-90.000, 90.000)
    #input lat/lng into citipy to receive city name
    city = (citipy.nearest_city(lat_test, lng_test)).city_name
    c_code = (citipy.nearest_city(lat_test, lng_test)).country_code
    
    try:
        #list setting for owm api wrapper
        settings = {"units": "imperial", "appid": api_key}
        # Get current weather JSON for city in loop
        current_weather = owm.get_current(city, **settings)

        #test if city name is in city_list
        if city in city_list:
            print(str(city) + ' is already in list. Trying another lat/lng')
            continue
        else:
            #add city to the list since it's not already
            print('City #' + str(city_count) + ' ' + str(city) +', ' + str(c_code) +' added to the list using OWM Wrapper, no link needed.')
            city_list.append(city)
            lat.append(lat_test)
            lng.append(lng_test)
            cntry_code.append(c_code)
            
            #create variable to input into current_weather api
            t_max = ["main.temp_max"]
            w_speed = ['wind.speed']
            humid = ['main.humidity']
            dt = ['dt']
            cloud = ['clouds.all']

            #apply current_weather function to get weather data
            temp_maxed = current_weather(*t_max)
            temp_wind = current_weather(*w_speed)
            temp_humid = current_weather(*humid)
            temp_dt = current_weather(*dt)
            temp_cloud = current_weather(*cloud)
            
            #append weather data in specified lists
            temp_max.append(temp_maxed)
            wind_speed.append(temp_wind)
            humidity.append(temp_humid)
            date_time.append(temp_dt)
            cloudiness.append(temp_cloud)
            
            #print added city to list
            
        #append counter to city_id list
        city_id.append(city_count) 
        #increment city counter
        city_count += 1
        
        
    #if error running city in owm, find a new city - go back to top of while loop
    except (KeyError, HTTPError):
        continue
print('----------------DONE COMPILING DATA---------------')
# Out:
# City #1 bredasdorp, za added to the list using OWM Wrapper, no link needed.
# City #2 albany, au added to the list using OWM Wrapper, no link needed.
# City #3 ushuaia, ar added to the list using OWM Wrapper, no link needed.
# City #4 scarborough, gb added to the list using OWM Wrapper, no link needed.
# City #5 dikson, ru added to the list using OWM Wrapper, no link needed.
# City #6 longyearbyen, sj added to the list using OWM Wrapper, no link needed.
# albany is already in list. Trying another lat/lng
# City #7 maniitsoq, gl added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# City #8 port elizabeth, za added to the list using OWM Wrapper, no link needed.
# City #9 narsaq, gl added to the list using OWM Wrapper, no link needed.
# City #10 camacha, pt added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #11 vardo, no added to the list using OWM Wrapper, no link needed.
# City #12 ribeira grande, pt added to the list using OWM Wrapper, no link needed.
# City #13 itarema, br added to the list using OWM Wrapper, no link needed.
# City #14 sinnamary, gf added to the list using OWM Wrapper, no link needed.
# City #15 bud, no added to the list using OWM Wrapper, no link needed.
# City #16 pocone, br added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #17 hithadhoo, mv added to the list using OWM Wrapper, no link needed.
# City #18 saint-philippe, re added to the list using OWM Wrapper, no link needed.
# City #19 castro, cl added to the list using OWM Wrapper, no link needed.
# longyearbyen is already in list. Trying another lat/lng
# City #20 sao joao da barra, br added to the list using OWM Wrapper, no link needed.
# City #21 east london, za added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #22 saint george, bm added to the list using OWM Wrapper, no link needed.
# City #23 tasiilaq, gl added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #24 tineo, es added to the list using OWM Wrapper, no link needed.
# City #25 port alfred, za added to the list using OWM Wrapper, no link needed.
# City #26 gonbad-e qabus, ir added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# City #27 ilulissat, gl added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #28 yar-sale, ru added to the list using OWM Wrapper, no link needed.
# City #29 nioro, ml added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #30 upernavik, gl added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #31 itacare, br added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# saint-philippe is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #32 san luis, ar added to the list using OWM Wrapper, no link needed.
# City #33 surt, ly added to the list using OWM Wrapper, no link needed.
# tasiilaq is already in list. Trying another lat/lng
# City #34 qaanaaq, gl added to the list using OWM Wrapper, no link needed.
# City #35 encruzilhada do sul, br added to the list using OWM Wrapper, no link needed.
# City #36 grindavik, is added to the list using OWM Wrapper, no link needed.
# City #37 clyde river, ca added to the list using OWM Wrapper, no link needed.
# City #38 puerto el triunfo, sv added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #39 miquelon, pm added to the list using OWM Wrapper, no link needed.
# hithadhoo is already in list. Trying another lat/lng
# City #40 cidreira, br added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# City #41 williamsport, us added to the list using OWM Wrapper, no link needed.
# City #42 mar del plata, ar added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# narsaq is already in list. Trying another lat/lng
# City #43 arraial do cabo, br added to the list using OWM Wrapper, no link needed.
# City #44 benguela, ao added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #45 hermanus, za added to the list using OWM Wrapper, no link needed.
# City #46 togur, ru added to the list using OWM Wrapper, no link needed.
# City #47 caravelas, br added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# City #48 kruisfontein, za added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #49 sistranda, no added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# tasiilaq is already in list. Trying another lat/lng
# City #50 asekeyevo, ru added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# City #51 bria, cf added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# City #52 luderitz, na added to the list using OWM Wrapper, no link needed.
# City #53 torbay, ca added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# City #54 dingle, ie added to the list using OWM Wrapper, no link needed.
# City #55 bar harbor, us added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #56 kilembe, ug added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #57 busselton, au added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# City #58 namibe, ao added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #59 los llanos de aridane, es added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #60 karachi, pk added to the list using OWM Wrapper, no link needed.
# upernavik is already in list. Trying another lat/lng
# City #61 kurchum, kz added to the list using OWM Wrapper, no link needed.
# City #62 faya, td added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# City #63 culebra, us added to the list using OWM Wrapper, no link needed.
# albany is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# City #64 nandurbar, in added to the list using OWM Wrapper, no link needed.
# City #65 challans, fr added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# cidreira is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #66 santa ana, pe added to the list using OWM Wrapper, no link needed.
# City #67 arlit, ne added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# City #68 high rock, bs added to the list using OWM Wrapper, no link needed.
# City #69 bela vista, br added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# City #70 takoradi, gh added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# City #71 jalu, ly added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# saint-philippe is already in list. Trying another lat/lng
# City #72 bambous virieux, mu added to the list using OWM Wrapper, no link needed.
# narsaq is already in list. Trying another lat/lng
# City #73 tiassale, ci added to the list using OWM Wrapper, no link needed.
# City #74 bandarbeyla, so added to the list using OWM Wrapper, no link needed.
# itarema is already in list. Trying another lat/lng
# City #75 gambela, et added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# City #76 taranto, it added to the list using OWM Wrapper, no link needed.
# City #77 beyneu, kz added to the list using OWM Wrapper, no link needed.
# dingle is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# City #78 bodden town, ky added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #79 alta floresta, br added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# ribeira grande is already in list. Trying another lat/lng
# City #80 georgetown, sh added to the list using OWM Wrapper, no link needed.
# narsaq is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #81 pankovka, ru added to the list using OWM Wrapper, no link needed.
# City #82 punta arenas, cl added to the list using OWM Wrapper, no link needed.
# City #83 axim, gh added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# City #84 jamestown, sh added to the list using OWM Wrapper, no link needed.
# City #85 ouesso, cg added to the list using OWM Wrapper, no link needed.
# City #86 praia, cv added to the list using OWM Wrapper, no link needed.
# narsaq is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# georgetown is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #87 necochea, ar added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# City #88 shakhtinsk, kz added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #89 francia, hn added to the list using OWM Wrapper, no link needed.
# City #90 khakhea, bw added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# kruisfontein is already in list. Trying another lat/lng
# City #91 bathsheba, bb added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# arraial do cabo is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #92 coquimbo, cl added to the list using OWM Wrapper, no link needed.
# jamestown is already in list. Trying another lat/lng
# City #93 porto de moz, br added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# City #94 ponta do sol, cv added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #95 krasnovishersk, ru added to the list using OWM Wrapper, no link needed.
# City #96 pimentel, pe added to the list using OWM Wrapper, no link needed.
# City #97 cape town, za added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #98 chuy, uy added to the list using OWM Wrapper, no link needed.
# City #99 la rioja, ar added to the list using OWM Wrapper, no link needed.
# City #100 codrington, ag added to the list using OWM Wrapper, no link needed.
# port elizabeth is already in list. Trying another lat/lng
# City #101 kalevala, ru added to the list using OWM Wrapper, no link needed.
# City #102 dom pedrito, br added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# cape town is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #103 raudeberg, no added to the list using OWM Wrapper, no link needed.
# port elizabeth is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #104 male, mv added to the list using OWM Wrapper, no link needed.
# mar del plata is already in list. Trying another lat/lng
# City #105 mangaratiba, br added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# City #106 dingli, mt added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# kruisfontein is already in list. Trying another lat/lng
# City #107 chakwal, pk added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #108 chapais, ca added to the list using OWM Wrapper, no link needed.
# upernavik is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# ilulissat is already in list. Trying another lat/lng
# kruisfontein is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #109 salalah, om added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# alta floresta is already in list. Trying another lat/lng
# City #110 sao filipe, cv added to the list using OWM Wrapper, no link needed.
# City #111 arkadak, ru added to the list using OWM Wrapper, no link needed.
# City #112 saint-paul, re added to the list using OWM Wrapper, no link needed.
# City #113 pisco, pe added to the list using OWM Wrapper, no link needed.
# City #114 pangnirtung, ca added to the list using OWM Wrapper, no link needed.
# City #115 kasongo, cd added to the list using OWM Wrapper, no link needed.
# City #116 sorland, no added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# salalah is already in list. Trying another lat/lng
# coquimbo is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# cape town is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# City #117 sambava, mg added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #118 carnarvon, au added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# cape town is already in list. Trying another lat/lng
# City #119 santa cruz, cr added to the list using OWM Wrapper, no link needed.
# City #120 boa vista, br added to the list using OWM Wrapper, no link needed.
# longyearbyen is already in list. Trying another lat/lng
# tasiilaq is already in list. Trying another lat/lng
# tasiilaq is already in list. Trying another lat/lng
# City #121 tazovskiy, ru added to the list using OWM Wrapper, no link needed.
# City #122 emba, kz added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# City #123 nalut, ly added to the list using OWM Wrapper, no link needed.
# narsaq is already in list. Trying another lat/lng
# ribeira grande is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #124 chimbote, pe added to the list using OWM Wrapper, no link needed.
# port elizabeth is already in list. Trying another lat/lng
# City #125 ous, ru added to the list using OWM Wrapper, no link needed.
# busselton is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# City #126 presidente dutra, br added to the list using OWM Wrapper, no link needed.
# City #127 husavik, is added to the list using OWM Wrapper, no link needed.
# City #128 gacko, ba added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #129 riyadh, sa added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# City #130 iqaluit, ca added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# City #131 margate, za added to the list using OWM Wrapper, no link needed.
# narsaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# mar del plata is already in list. Trying another lat/lng
# City #132 senanga, zm added to the list using OWM Wrapper, no link needed.
# port elizabeth is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #133 natal, br added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# chuy is already in list. Trying another lat/lng
# punta arenas is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# saint george is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #134 abohar, in added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# tasiilaq is already in list. Trying another lat/lng
# City #135 ihtiman, bg added to the list using OWM Wrapper, no link needed.
# City #136 comodoro rivadavia, ar added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# City #137 bonavista, ca added to the list using OWM Wrapper, no link needed.
# City #138 pachino, it added to the list using OWM Wrapper, no link needed.
# City #139 mehamn, no added to the list using OWM Wrapper, no link needed.
# City #140 katsina, ng added to the list using OWM Wrapper, no link needed.
# longyearbyen is already in list. Trying another lat/lng
# City #141 kintampo, gh added to the list using OWM Wrapper, no link needed.
# chuy is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #142 jizan, sa added to the list using OWM Wrapper, no link needed.
# busselton is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #143 diffa, ne added to the list using OWM Wrapper, no link needed.
# City #144 pontes e lacerda, br added to the list using OWM Wrapper, no link needed.
# City #145 sao joaquim, br added to the list using OWM Wrapper, no link needed.
# City #146 mezdra, bg added to the list using OWM Wrapper, no link needed.
# City #147 nanortalik, gl added to the list using OWM Wrapper, no link needed.
# City #148 saldanha, za added to the list using OWM Wrapper, no link needed.
# saint george is already in list. Trying another lat/lng
# ribeira grande is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# sao joao da barra is already in list. Trying another lat/lng
# City #149 asyut, eg added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# ilulissat is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# City #150 gobabis, na added to the list using OWM Wrapper, no link needed.
# port elizabeth is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# City #151 havoysund, no added to the list using OWM Wrapper, no link needed.
# City #152 sevierville, us added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# hithadhoo is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# City #153 ponta delgada, pt added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# City #154 montepuez, mz added to the list using OWM Wrapper, no link needed.
# ponta do sol is already in list. Trying another lat/lng
# City #155 mangrol, in added to the list using OWM Wrapper, no link needed.
# arlit is already in list. Trying another lat/lng
# City #156 loukhi, ru added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# sao filipe is already in list. Trying another lat/lng
# bathsheba is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# tasiilaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# mar del plata is already in list. Trying another lat/lng
# saint-philippe is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #157 orcopampa, pe added to the list using OWM Wrapper, no link needed.
# longyearbyen is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #158 huambo, ao added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# arraial do cabo is already in list. Trying another lat/lng
# ponta do sol is already in list. Trying another lat/lng
# arraial do cabo is already in list. Trying another lat/lng
# City #159 bara, sd added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# bodden town is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# sorland is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# castro is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# mar del plata is already in list. Trying another lat/lng
# City #160 northampton, us added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ponta do sol is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# City #161 diamantina, br added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #162 sao gabriel da cachoeira, br added to the list using OWM Wrapper, no link needed.
# City #163 trelew, ar added to the list using OWM Wrapper, no link needed.
# City #164 vilhena, br added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# mehamn is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# City #165 la primavera, co added to the list using OWM Wrapper, no link needed.
# City #166 tsumeb, na added to the list using OWM Wrapper, no link needed.
# City #167 la libertad, sv added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# City #168 la labor, hn added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# City #169 lafiagi, ng added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# vilhena is already in list. Trying another lat/lng
# City #170 bastia, fr added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# bathsheba is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# hithadhoo is already in list. Trying another lat/lng
# City #171 kozhva, ru added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #172 lagoa, pt added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# City #173 dolores, ar added to the list using OWM Wrapper, no link needed.
# port elizabeth is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# bambous virieux is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# coquimbo is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #174 dergachi, ru added to the list using OWM Wrapper, no link needed.
# punta arenas is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# cape town is already in list. Trying another lat/lng
# saint-philippe is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# City #175 kambove, cd added to the list using OWM Wrapper, no link needed.
# torbay is already in list. Trying another lat/lng
# City #176 hit, iq added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #177 santa rosa, ar added to the list using OWM Wrapper, no link needed.
# City #178 vestmanna, fo added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# tazovskiy is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# arraial do cabo is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #179 aden, ye added to the list using OWM Wrapper, no link needed.
# chuy is already in list. Trying another lat/lng
# torbay is already in list. Trying another lat/lng
# narsaq is already in list. Trying another lat/lng
# City #180 mayumba, ga added to the list using OWM Wrapper, no link needed.
# longyearbyen is already in list. Trying another lat/lng
# City #181 bushenyi, ug added to the list using OWM Wrapper, no link needed.
# busselton is already in list. Trying another lat/lng
# saint george is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# riyadh is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# kruisfontein is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# nanortalik is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# punta arenas is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #182 inverness, ca added to the list using OWM Wrapper, no link needed.
# City #183 viedma, ar added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# City #184 touros, br added to the list using OWM Wrapper, no link needed.
# clyde river is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# namibe is already in list. Trying another lat/lng
# City #185 urengoy, ru added to the list using OWM Wrapper, no link needed.
# City #186 tsogni, ga added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# tasiilaq is already in list. Trying another lat/lng
# City #187 yurginskoye, ru added to the list using OWM Wrapper, no link needed.
# bambous virieux is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# punta arenas is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #188 lebu, cl added to the list using OWM Wrapper, no link needed.
# port elizabeth is already in list. Trying another lat/lng
# arraial do cabo is already in list. Trying another lat/lng
# ribeira grande is already in list. Trying another lat/lng
# City #189 khorramshahr, ir added to the list using OWM Wrapper, no link needed.
# port alfred is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# punta arenas is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# City #190 maragogi, br added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# saldanha is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #191 kumylzhenskaya, ru added to the list using OWM Wrapper, no link needed.
# City #192 hofn, is added to the list using OWM Wrapper, no link needed.
# longyearbyen is already in list. Trying another lat/lng
# City #193 lagos, pt added to the list using OWM Wrapper, no link needed.
# east london is already in list. Trying another lat/lng
# City #194 nagaur, in added to the list using OWM Wrapper, no link needed.
# City #195 independencia, br added to the list using OWM Wrapper, no link needed.
# port elizabeth is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #196 sainte-agathe-des-monts, ca added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #197 oranjemund, na added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #198 taoudenni, ml added to the list using OWM Wrapper, no link needed.
# cape town is already in list. Trying another lat/lng
# City #199 bhaderwah, in added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# City #200 cajaruro, pe added to the list using OWM Wrapper, no link needed.
# chuy is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #201 victoria, sc added to the list using OWM Wrapper, no link needed.
# City #202 rio cuarto, ar added to the list using OWM Wrapper, no link needed.
# castro is already in list. Trying another lat/lng
# City #203 thomaston, us added to the list using OWM Wrapper, no link needed.
# albany is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #204 qasigiannguit, gl added to the list using OWM Wrapper, no link needed.
# City #205 esil, kz added to the list using OWM Wrapper, no link needed.
# City #206 itaituba, br added to the list using OWM Wrapper, no link needed.
# City #207 lobito, ao added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #208 oeiras do para, br added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #209 mariental, na added to the list using OWM Wrapper, no link needed.
# busselton is already in list. Trying another lat/lng
# City #210 kot diji, pk added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# clyde river is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# City #211 douentza, ml added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #212 gari, ru added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# narsaq is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #213 asini, gr added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #214 floriano, br added to the list using OWM Wrapper, no link needed.
# clyde river is already in list. Trying another lat/lng
# City #215 vila velha, br added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# City #216 saquarema, br added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# kruisfontein is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# City #217 luanda, ao added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #218 souillac, mu added to the list using OWM Wrapper, no link needed.
# albany is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# torbay is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# City #219 sao joao do paraiso, br added to the list using OWM Wrapper, no link needed.
# City #220 bubaque, gw added to the list using OWM Wrapper, no link needed.
# saint george is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #221 sestri levante, it added to the list using OWM Wrapper, no link needed.
# los llanos de aridane is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# souillac is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# hithadhoo is already in list. Trying another lat/lng
# mar del plata is already in list. Trying another lat/lng
# sao filipe is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# City #222 kralendijk, an added to the list using OWM Wrapper, no link needed.
# albany is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# narsaq is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# mar del plata is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# City #223 matadi, cd added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# oranjemund is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #224 bedum, nl added to the list using OWM Wrapper, no link needed.
# salalah is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# ponta do sol is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# cape town is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# sambava is already in list. Trying another lat/lng
# City #225 corner brook, ca added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# City #226 revin, fr added to the list using OWM Wrapper, no link needed.
# City #227 at-bashi, kg added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #228 antofagasta, cl added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# City #229 mezen, ru added to the list using OWM Wrapper, no link needed.
# jamestown is already in list. Trying another lat/lng
# saint-philippe is already in list. Trying another lat/lng
# cape town is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #230 raisen, in added to the list using OWM Wrapper, no link needed.
# ...
# viedma is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# bandarbeyla is already in list. Trying another lat/lng
# castro is already in list. Trying another lat/lng
# vardo is already in list. Trying another lat/lng
# ciudad bolivar is already in list. Trying another lat/lng
# City #461 durgapur, in added to the list using OWM Wrapper, no link needed.
# mar del plata is already in list. Trying another lat/lng
# City #462 suffolk, us added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# hithadhoo is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# City #463 donskoye, ru added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# port-gentil is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# iqaluit is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# punta arenas is already in list. Trying another lat/lng
# codrington is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #464 taltal, cl added to the list using OWM Wrapper, no link needed.
# City #465 manali, in added to the list using OWM Wrapper, no link needed.
# City #466 cockburn town, tc added to the list using OWM Wrapper, no link needed.
# upernavik is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #467 duvan, ru added to the list using OWM Wrapper, no link needed.
# City #468 westport, ie added to the list using OWM Wrapper, no link needed.
# City #469 sayyan, ye added to the list using OWM Wrapper, no link needed.
# chuy is already in list. Trying another lat/lng
# City #470 itupiranga, br added to the list using OWM Wrapper, no link needed.
# tasiilaq is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# bubaque is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# City #471 suhut, tr added to the list using OWM Wrapper, no link needed.
# hofn is already in list. Trying another lat/lng
# vestmannaeyjar is already in list. Trying another lat/lng
# narsaq is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# City #472 robore, bo added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #473 lumeje, ao added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# narsaq is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# City #474 uruzgan, af added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# chuy is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# saint-georges is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# sisimiut is already in list. Trying another lat/lng
# lagoa is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #475 verkhnyaya sinyachikha, ru added to the list using OWM Wrapper, no link needed.
# narsaq is already in list. Trying another lat/lng
# namibe is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #476 wawa, ca added to the list using OWM Wrapper, no link needed.
# saint-philippe is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ribeira grande is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# arraial do cabo is already in list. Trying another lat/lng
# sao filipe is already in list. Trying another lat/lng
# kruisfontein is already in list. Trying another lat/lng
# sinnamary is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# santa rosa is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# narsaq is already in list. Trying another lat/lng
# axim is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #477 desbiens, ca added to the list using OWM Wrapper, no link needed.
# City #478 saint anthony, ca added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# east london is already in list. Trying another lat/lng
# georgetown is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #479 belmopan, bz added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #480 sciacca, it added to the list using OWM Wrapper, no link needed.
# bredasdorp is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #481 pirai, br added to the list using OWM Wrapper, no link needed.
# kavaratti is already in list. Trying another lat/lng
# hit is already in list. Trying another lat/lng
# City #482 blagoveshchenka, ru added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# sinnamary is already in list. Trying another lat/lng
# punta arenas is already in list. Trying another lat/lng
# iqaluit is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #483 la asuncion, ve added to the list using OWM Wrapper, no link needed.
# obo is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# codrington is already in list. Trying another lat/lng
# City #484 sohag, eg added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #485 bonfim, br added to the list using OWM Wrapper, no link needed.
# City #486 taraz, kz added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# City #487 mahbubnagar, in added to the list using OWM Wrapper, no link needed.
# tazovskiy is already in list. Trying another lat/lng
# ribeira grande is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ribeira grande is already in list. Trying another lat/lng
# thinadhoo is already in list. Trying another lat/lng
# nioro is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# rocha is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #488 marsh harbour, bs added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# busselton is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# havoysund is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #489 nantucket, us added to the list using OWM Wrapper, no link needed.
# ribeira grande is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# nantucket is already in list. Trying another lat/lng
# City #490 chicama, pe added to the list using OWM Wrapper, no link needed.
# husavik is already in list. Trying another lat/lng
# mahebourg is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# taoudenni is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# City #491 goundam, ml added to the list using OWM Wrapper, no link needed.
# longyearbyen is already in list. Trying another lat/lng
# mahebourg is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# saint-pierre is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #492 japura, br added to the list using OWM Wrapper, no link needed.
# longyearbyen is already in list. Trying another lat/lng
# klaksvik is already in list. Trying another lat/lng
# City #493 neuquen, ar added to the list using OWM Wrapper, no link needed.
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# umm lajj is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# bredasdorp is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# bambous virieux is already in list. Trying another lat/lng
# City #494 kostino, ru added to the list using OWM Wrapper, no link needed.
# hermanus is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# mar del plata is already in list. Trying another lat/lng
# georgetown is already in list. Trying another lat/lng
# City #495 iracoubo, gf added to the list using OWM Wrapper, no link needed.
# dingle is already in list. Trying another lat/lng
# lebu is already in list. Trying another lat/lng
# port elizabeth is already in list. Trying another lat/lng
# chuy is already in list. Trying another lat/lng
# ostrovnoy is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# ilulissat is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# City #496 cookeville, us added to the list using OWM Wrapper, no link needed.
# henties bay is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# cape town is already in list. Trying another lat/lng
# cockburn town is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# westport is already in list. Trying another lat/lng
# City #497 gat, ly added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# arraial do cabo is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# hithadhoo is already in list. Trying another lat/lng
# albany is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# arraial do cabo is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #498 olinda, br added to the list using OWM Wrapper, no link needed.
# albany is already in list. Trying another lat/lng
# cape town is already in list. Trying another lat/lng
# mar del plata is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# City #499 kindia, gn added to the list using OWM Wrapper, no link needed.
# punta arenas is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# cascais is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# dikson is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# punta arenas is already in list. Trying another lat/lng
# upernavik is already in list. Trying another lat/lng
# port alfred is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# vestmannaeyjar is already in list. Trying another lat/lng
# hermanus is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ilulissat is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #500 nisia floresta, br added to the list using OWM Wrapper, no link needed.
# ----------------DONE COMPILING DATA---------------

# %%
#create data frame with lists
city_info = pd.DataFrame({'City ID' : city_id, 'City': city_list, 'Country' : cntry_code, 'Lat' : lat, 'Lng': lng, 'Max Temp' : temp_max, 'Wind Speed' : wind_speed, \
                          'Humidity' : humidity, 'Date': date_time, 'Cloudiness' : cloudiness}, index=None)
#place columns in order

city_info = city_info[['City ID', 'City','Country', 'Date', 'Cloudiness', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']]
#city_info['Lat'] = city_info['Lat'].map("{:,.3f}".format)
#city_info['Lng'] = city_info['Lng'].map("{:,.3f}".format)


city_info.to_csv('city_info_data.csv', index=False)
city_info.head(25)
# Out:
#     City ID               City Country        Date  Cloudiness  Humidity  \
# 0         1         bredasdorp      za  1522771200          44        68
# 1         2             albany      au  1522772880          90        59
# 2         3            ushuaia      ar  1522771200          40        81
# 3         4        scarborough      gb  1522770600          20        81
# 4         5             dikson      ru  1522775107           0        65
# 5         6       longyearbyen      sj  1522770600          20        51
# 6         7          maniitsoq      gl  1522775525           0        92
# 7         8     port elizabeth      za  1522774500          90        93
# 8         9             narsaq      gl  1522774200          40        30
# 9        10            camacha      pt  1522773000          20        55
# 10       11              vardo      no  1522774020          90        70
# 11       12     ribeira grande      pt  1522773000          20        55
# 12       13            itarema      br  1522775412          36        97
# 13       14          sinnamary      gf  1522775533          56        90
# 14       15                bud      no  1522774200           0        38
# 15       16             pocone      br  1522775606          20        84
# 16       17          hithadhoo      mv  1522775137          56       100
# 17       18     saint-philippe      re  1522772100          90        38
# 18       19             castro      cl  1522774854          92        95
# 19       20  sao joao da barra      br  1522771200          20        49
# 20       21        east london      za  1522771200           0        94
# 21       22       saint george      bm  1522772400           0        67
# 22       23           tasiilaq      gl  1522774200          90        67
# 23       24              tineo      es  1522774800          40        34
# 24       25        port alfred      za  1522774978          44        95
#
#            Lat        Lng  Max Temp  Wind Speed
# 0  -136.111516  18.889634     69.80       13.87
# 1  -172.892835  77.401962     44.60       12.75
# 2  -176.708897 -86.149164     46.40        7.18
# 3    55.808525   1.158911     57.20        8.05
# 4   112.929878  63.972473     -8.18       11.21
# 5   172.576261  40.942160     10.40       11.41
# 6    61.041012 -57.626596     29.99        3.60
# 7  -115.077240  45.925005     44.60        9.17
# 8    93.718470 -60.382395     42.80        6.93
# 9    38.530843 -15.663060     68.00       13.87
# 10   77.856544  33.725711     50.00        9.17
# 11   36.762449 -28.958806     62.60       16.11
# 12    8.885307 -36.013069     81.38        9.31
# 13   15.330923 -46.795214     82.01        8.97
# 14   72.913454   3.019365     39.20        8.05
# 15  -16.710864 -57.216363     86.51        3.60
# 16  -11.864236  85.847073     84.71        5.39
# 17  -59.520594  72.357646     44.60        2.24
# 18  -48.338769 -81.512641     58.88       12.21
# 19  -31.918402 -25.061071     91.40       17.02
# 20  -40.822395  32.490562     69.80        5.82
# 21   30.359382 -60.969377     59.00        6.93
# 22   73.041072 -39.854254     23.00       14.99
# 23   43.457974  -6.391386     64.40       19.46
# 24  -85.532807  39.890712     70.13        3.04

# %%
#create City Latitude vs. Max Temperature(4/3/17) scatter plot

#set seadboard style & size of plot
sns.set_style("darkgrid")
plt.figure(figsize=(12, 5))

#setup plot
urban_plot = plt.scatter(city_info['Lat'], city_info['Max Temp'],  facecolors="red", edgecolors="black",
            alpha=0.75)

plt.title("City Latitude vs. Max Temperature(4/3/17)")
plt.xlabel("Latitude")
#plt.xlim([-180,180])
plt.ylabel("Max Temperature")
plt.savefig("Lat_VS_TMax.png")
plt.show()

#--------------OBSERVABLE TREMD #1-----------------#
#Temperature is a lot higher around the equater, but more concentration of colder cities down of the equater in this data set.

# %%
#create City Latitude vs. Humidity(4/3/17) scatter plot

#set seadboard style & size of plot
sns.set_style("darkgrid")
plt.figure(figsize=(12, 5))

#setup plot
urban_plot = plt.scatter(city_info['Lat'], city_info['Humidity'],  facecolors="blue", edgecolors="black",
            alpha=0.75)

plt.title("City Latitude vs. Humidity(4/3/17)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("Lat_VS_Humid.png")
plt.show()
#--------------OBSERVABLE TREMD #2-----------------#
#As expected humidity is higher around the equater.

# %%
#create City Latitude vs. Cloudiness (4/3/17) scatter plot

#set seadboard style & size of plot
sns.set_style("darkgrid")
plt.figure(figsize=(12, 5))

#setup plot
urban_plot = plt.scatter(city_info['Lat'], city_info['Cloudiness'],  facecolors="yellow", edgecolors="black",
            alpha=0.75)

plt.title("City Latitude vs. Cloudiness (4/3/17)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("Lat_VS_Cloud.png")
plt.show()

#--------------OBSERVABLE TREMD #1-----------------#
#Closer towards the equator leads to higher humidity and more clouds.

# %%
#create City Latitude vs. Wind Speed (4/3/17) scatter plot

#set seadboard style & size of plot
sns.set_style("darkgrid")
plt.figure(figsize=(12, 5))

#setup plot
urban_plot = plt.scatter(city_info['Lat'], city_info['Wind Speed'],  facecolors="green", edgecolors="black",
            alpha=0.75)

plt.title("City Latitude vs. Wind Speed (4/3/17)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")
plt.savefig("Lat_VS_Wind.png")
plt.show()
