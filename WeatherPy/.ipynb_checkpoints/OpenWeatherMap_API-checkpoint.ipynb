# %%
from citipy import citipy
import numpy as np
import pandas as pd
import random
from config import api_key
import json
import requests
from pprint import pprint
import openweathermapy.core as owm
from urllib.error import HTTPError
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#setup lists for all data needed
city_list = []
cntry_code =[]
city_id = []
lat = []
lng= []
temp_max= []
wind_speed = []
humidity = []
date_time = []
cloudiness = []

#city counter
city_count = 1

#while loop for 500 unique cities
while city_count <501:
    #receive from randomn generator a random lat/lng
    lat_test = random.uniform(-180.000, 180.000)
    lng_test = random.uniform(-90.000, 90.000)
    #input lat/lng into citipy to receive city name
    city = (citipy.nearest_city(lat_test, lng_test)).city_name
    c_code = (citipy.nearest_city(lat_test, lng_test)).country_code
    
    try:
        #list setting for owm api wrapper
        settings = {"units": "imperial", "appid": api_key}
        # Get current weather JSON for city in loop
        current_weather = owm.get_current(city, **settings)

        #test if city name is in city_list
        if city in city_list:
            print(str(city) + ' is already in list. Trying another lat/lng')
            continue
        else:
            #add city to the list since it's not already
            print('City #' + str(city_count) + ' ' + str(city) +', ' + str(c_code) +' added to the list using OWM Wrapper, no link needed.')
            city_list.append(city)
            lat.append(lat_test)
            lng.append(lng_test)
            cntry_code.append(c_code)
            
            #create variable to input into current_weather api
            t_max = ["main.temp_max"]
            w_speed = ['wind.speed']
            humid = ['main.humidity']
            dt = ['dt']
            cloud = ['clouds.all']

            #apply current_weather function to get weather data
            temp_maxed = current_weather(*t_max)
            temp_wind = current_weather(*w_speed)
            temp_humid = current_weather(*humid)
            temp_dt = current_weather(*dt)
            temp_cloud = current_weather(*cloud)
            
            #append weather data in specified lists
            temp_max.append(temp_maxed)
            wind_speed.append(temp_wind)
            humidity.append(temp_humid)
            date_time.append(temp_dt)
            cloudiness.append(temp_cloud)
            
            #print added city to list
            
        #append counter to city_id list
        city_id.append(city_count) 
        #increment city counter
        city_count += 1
        
        
    #if error running city in owm, find a new city - go back to top of while loop
    except (KeyError, HTTPError):
        continue
print('----------------DONE COMPILING DATA---------------')
# Out:
# City #1 mount pleasant, us added to the list using OWM Wrapper, no link needed.
# City #2 port alfred, za added to the list using OWM Wrapper, no link needed.
# City #3 albany, au added to the list using OWM Wrapper, no link needed.
# albany is already in list. Trying another lat/lng
# City #4 ushuaia, ar added to the list using OWM Wrapper, no link needed.
# City #5 zabol, ir added to the list using OWM Wrapper, no link needed.
# City #6 doha, kw added to the list using OWM Wrapper, no link needed.
# City #7 longyearbyen, sj added to the list using OWM Wrapper, no link needed.
# City #8 tall kayf, iq added to the list using OWM Wrapper, no link needed.
# City #9 salalah, om added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# longyearbyen is already in list. Trying another lat/lng
# City #10 qaanaaq, gl added to the list using OWM Wrapper, no link needed.
# City #11 viedma, ar added to the list using OWM Wrapper, no link needed.
# City #12 kadyy, ru added to the list using OWM Wrapper, no link needed.
# City #13 kibre mengist, et added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# City #14 upernavik, gl added to the list using OWM Wrapper, no link needed.
# City #15 husavik, is added to the list using OWM Wrapper, no link needed.
# albany is already in list. Trying another lat/lng
# City #16 jamestown, sh added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# City #17 tasiilaq, gl added to the list using OWM Wrapper, no link needed.
# City #18 acari, pe added to the list using OWM Wrapper, no link needed.
# City #19 port elizabeth, za added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# City #20 taoudenni, ml added to the list using OWM Wrapper, no link needed.
# qaanaaq is already in list. Trying another lat/lng
# City #21 mahebourg, mu added to the list using OWM Wrapper, no link needed.
# City #22 klaksvik, fo added to the list using OWM Wrapper, no link needed.
# ushuaia is already in list. Trying another lat/lng
# ushuaia is already in list. Trying another lat/lng
# qaanaaq is already in list. Trying another lat/lng
# City #23 ouesso, cg added to the list using OWM Wrapper, no link needed.
# upernavik is already in list. Trying another lat/lng
# mahebourg is already in list. Trying another lat/lng
# jamestown is already in list. Trying another lat/lng
# City #24 marsh harbour, bs added to the list using OWM Wrapper, no link needed.
# ----------------DONE COMPILING DATA---------------

# %%
city_list
# Out:
# ['coquimbo',
#  'teguise',
#  'qaanaaq',
#  'ushuaia',
#  'port alfred',
#  'cape town',
#  'praia da vitoria',
#  'longyearbyen',
#  'hermanus',
#  'tasiilaq',
#  'port elizabeth',
#  'dikson',
#  'nantucket',
#  'lebu',
#  'jorpeland',
#  'garmsar',
#  'mar del plata',
#  'boden',
#  'arraial do cabo',
#  'albany',
#  'narsaq',
#  'punta arenas',
#  'santa cruz de la palma',
#  'tazovskiy',
#  'georgetown',
#  'mahebourg',
#  'springbok',
#  'codrington',
#  'bredasdorp',
#  'busselton',
#  'oruro',
#  'victoria',
#  'najran',
#  'isoka',
#  'jamestown',
#  'buraydah',
#  'leshukonskoye',
#  'khed brahma',
#  'chuy',
#  'viedma',
#  'castro',
#  'pangoa',
#  'sigulda',
#  'husavik',
#  'talara',
#  'kruisfontein',
#  'mwinilunga',
#  'lagunas',
#  'atar',
#  'saint-augustin',
#  'necochea',
#  'new albany',
#  'saint anthony',
#  'upernavik',
#  'sorland',
#  'kavaratti',
#  'elizabeth city',
#  'kangundo',
#  'palmares do sul',
#  'klaksvik',
#  'lima',
#  'ilulissat',
#  'elat',
#  'cascais',
#  'sarankhola',
#  'yevsino',
#  'hemel hempstead',
#  'sydney mines',
#  'vila velha',
#  'hofn',
#  'bambous virieux',
#  'iqaluit',
#  'hithadhoo',
#  'gao',
#  'parrsboro',
#  'aleksandrov gay',
#  'ribeira grande',
#  'sao felix do xingu',
#  'sao geraldo do araguaia',
#  'torbay',
#  'jhargram',
#  'san luis',
#  'bolobo',
#  'alta floresta',
#  'lusambo',
#  'catio',
#  'guanica',
#  'ust-kulom',
#  'konstantynow lodzki',
#  'bathsheba',
#  'sao joao da barra',
#  'listvyanskiy',
#  'sirjan',
#  'walvis bay',
#  'mehamn',
#  'porto novo',
#  'sao filipe',
#  'kamina',
#  'saldanha',
#  'nalut']

# %%
#create data frame with lists
city_info = pd.DataFrame({'City ID' : city_id, 'City': city_list, 'Country' : cntry_code, 'Lat' : lat, 'Lng': lng, 'Max Temp' : temp_max, 'Wind Speed' : wind_speed, \
                          'Humidity' : humidity, 'Date': date_time, 'Cloudiness' : cloudiness}, index=None)
#place columns in order

city_info = city_info[['City ID', 'City','Country', 'Date', 'Cloudiness', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']]
#city_info['Lat'] = city_info['Lat'].map("{:,.3f}".format)
#city_info['Lng'] = city_info['Lng'].map("{:,.3f}".format)


city_info.to_csv('city_info_data.csv', index=False)
city_info.head(25)
# Out:
#     City ID            City Country        Date  Cloudiness  Humidity  \
# 0         1  mount pleasant      us  1522772100          40        65
# 1         2     port alfred      za  1522774978          44        95
# 2         3          albany      au  1522774260          90        80
# 3         4         ushuaia      ar  1522771200          40        81
# 4         5           zabol      ir  1522771200           0        26
# 5         6            doha      kw  1522771200           0        42
# 6         7    longyearbyen      sj  1522770600          20        51
# 7         8       tall kayf      iq  1522774800           0        31
# 8         9         salalah      om  1522770600          20        78
# 9        10         qaanaaq      gl  1522774991           0        84
# 10       11          viedma      ar  1522774983           0        45
# 11       12           kadyy      ru  1522774984          56        93
# 12       13   kibre mengist      et  1522774984          80        75
# 13       14       upernavik      gl  1522774985          80       100
# 14       15         husavik      is  1522774994           0       100
# 15       16       jamestown      sh  1522774987           0        84
# 16       17        tasiilaq      gl  1522770600          90        67
# 17       18           acari      pe  1522774988           8        82
# 18       19  port elizabeth      za  1522774500          90        93
# 19       20       taoudenni      ml  1522774998           0        10
# 20       21       mahebourg      mu  1522771200          90        83
# 21       22        klaksvik      fo  1522772400           0       100
# 22       23          ouesso      cg  1522775001          48        65
# 23       24   marsh harbour      bs  1522775002          56        99
#
#            Lat        Lng  Max Temp  Wind Speed
# 0    31.808723 -79.059241     77.00       24.16
# 1  -108.607190  49.134356     70.13        3.04
# 2  -110.726892  88.075395     44.60        9.17
# 3   -95.630036 -48.185831     46.40        7.18
# 4    30.264600  60.101946     78.80        9.17
# 5    28.450561  46.640759     80.60        3.36
# 6    94.881195  31.194478     10.40       11.41
# 7    35.987471  42.927535     59.00        6.93
# 8    15.394241  55.425535     80.60        6.93
# 9   139.101601 -59.899736      4.97        9.98
# 10  -41.256375 -61.608770     81.29       10.65
# 11   57.501539  43.434319     33.95        9.98
# 12    5.243320  40.282701     65.99        4.72
# 13  109.793981 -41.038710     18.65        9.42
# 14   68.428073 -15.057006     17.12        4.72
# 15  -23.621841  -7.436441     46.73        5.95
# 16   72.598383 -32.918544     23.00       16.11
# 17  -17.633644 -75.535821     81.92        6.73
# 18 -127.360796  47.843767     44.60        9.17
# 19   25.572008  -3.586093     93.35        8.52
# 20  -50.890746  77.376125     82.40        9.17
# 21   71.038471  -3.674178     32.00        9.17
# 22    1.256527  16.756832     84.89        3.49
# 23   30.224483 -72.635857     74.81       10.42

# %%
#create City Latitude vs. Max Temperature(4/3/17) scatter plot

#set seadboard style & size of plot
sns.set_style("darkgrid")
plt.figure(figsize=(12, 5))

#setup plot
urban_plot = plt.scatter(city_info['Lat'], city_info['Max Temp'],  facecolors="red", edgecolors="black",
            alpha=0.75)

plt.title("City Latitude vs. Max Temperature(4/3/17)")
plt.xlabel("Latitude")
#plt.xlim([-180,180])
plt.ylabel("Max Temperature")
plt.savefig("Lat_VS_TMax.png")
plt.show()

# %%
#create City Latitude vs. Humidity(4/3/17) scatter plot

#set seadboard style & size of plot
sns.set_style("darkgrid")
plt.figure(figsize=(12, 5))

#setup plot
urban_plot = plt.scatter(city_info['Lat'], city_info['Humidity'],  facecolors="blue", edgecolors="black",
            alpha=0.75)

plt.title("City Latitude vs. Humidity(4/3/17)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("Lat_VS_Humid.png")
plt.show()

# %%
#create City Latitude vs. Cloudiness (4/3/17) scatter plot

#set seadboard style & size of plot
sns.set_style("darkgrid")
plt.figure(figsize=(12, 5))

#setup plot
urban_plot = plt.scatter(city_info['Lat'], city_info['Cloudiness'],  facecolors="yellow", edgecolors="black",
            alpha=0.75)

plt.title("City Latitude vs. Cloudiness (4/3/17)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("Lat_VS_Cloud.png")
plt.show()

# %%
#create City Latitude vs. Wind Speed (4/3/17) scatter plot

#set seadboard style & size of plot
sns.set_style("darkgrid")
plt.figure(figsize=(12, 5))

#setup plot
urban_plot = plt.scatter(city_info['Lat'], city_info['Wind Speed'],  facecolors="green", edgecolors="black",
            alpha=0.75)

plt.title("City Latitude vs. Wind Speed (4/3/17)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")
plt.savefig("Lat_VS_Wind.png")
plt.show()
